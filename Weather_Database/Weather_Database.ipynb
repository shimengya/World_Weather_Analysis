# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# # Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
# YOUR CODE HERE
len(cities)
# Out:
# 754

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# city_weather = requests.get(city_url)
# city_weather.json()
# city_lat = city_weather["coord"]["lat"]
# city_lng = city_weather["coord"]["lon"]
# city_max_temp = city_weather["main"]["temp_max"]
# city_humidity = city_weather["main"]["humidity"]
# city_clouds = city_weather["clouds"]["all"]
# city_wind = city_weather["wind"]["speed"]
# city_country = city_weather["sys"]["country"]
# weather_description = city_weather["weather"][0]["description"]

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
    #     print(city_weather)
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        
    # Convert the date to ISO standard.
    #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

    # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | pitanga
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | souillac
# Processing Record 8 of Set 1 | sinnamary
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | tigzirt
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | hasaki
# Processing Record 16 of Set 1 | russell
# Processing Record 17 of Set 1 | vila franca do campo
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | georgetown
# Processing Record 22 of Set 1 | gaya
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | lompoc
# Processing Record 25 of Set 1 | qaanaaq
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | calabozo
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | luderitz
# Processing Record 30 of Set 1 | port-cartier
# Processing Record 31 of Set 1 | mezhdurechensk
# Processing Record 32 of Set 1 | addi ugri
# City not found. Skipping...
# Processing Record 33 of Set 1 | okhotsk
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | dikson
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | vostok
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | rundu
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | gobabis
# Processing Record 42 of Set 1 | kushima
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | muisne
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | port-gentil
# Processing Record 48 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 1 | sao joao da barra
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | bandarbeyla
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | richards bay
# Processing Record 8 of Set 2 | wilmington
# Processing Record 9 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 10 of Set 2 | tocopilla
# Processing Record 11 of Set 2 | belyy yar
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | teguldet
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | maceio
# Processing Record 17 of Set 2 | paamiut
# Processing Record 18 of Set 2 | clyde river
# Processing Record 19 of Set 2 | tingrela
# City not found. Skipping...
# Processing Record 20 of Set 2 | mehamn
# Processing Record 21 of Set 2 | bubaque
# Processing Record 22 of Set 2 | tshikapa
# Processing Record 23 of Set 2 | cayenne
# Processing Record 24 of Set 2 | lagoa
# Processing Record 25 of Set 2 | cam ranh
# Processing Record 26 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 2 | yelizovo
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | fort frances
# Processing Record 32 of Set 2 | dingle
# Processing Record 33 of Set 2 | airai
# Processing Record 34 of Set 2 | isangel
# Processing Record 35 of Set 2 | husavik
# Processing Record 36 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 2 | santa rosa
# Processing Record 38 of Set 2 | leshukonskoye
# Processing Record 39 of Set 2 | abha
# Processing Record 40 of Set 2 | saint-augustin
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | ubon ratchathani
# Processing Record 43 of Set 2 | rio gallegos
# Processing Record 44 of Set 2 | verkhnevilyuysk
# Processing Record 45 of Set 2 | presidente olegario
# Processing Record 46 of Set 2 | trencin
# Processing Record 47 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 2 | nanortalik
# Processing Record 49 of Set 2 | port augusta
# Processing Record 50 of Set 2 | carmelo
# Processing Record 1 of Set 3 | tuscaloosa
# Processing Record 2 of Set 3 | port hedland
# Processing Record 3 of Set 3 | narsaq
# Processing Record 4 of Set 3 | lincoln
# Processing Record 5 of Set 3 | ryotsu
# Processing Record 6 of Set 3 | indramayu
# Processing Record 7 of Set 3 | vangaindrano
# Processing Record 8 of Set 3 | tuatapere
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | phuket
# Processing Record 11 of Set 3 | leh
# Processing Record 12 of Set 3 | komsomolskiy
# Processing Record 13 of Set 3 | sharjah
# Processing Record 14 of Set 3 | kodiak
# Processing Record 15 of Set 3 | kushchevskaya
# Processing Record 16 of Set 3 | itoman
# Processing Record 17 of Set 3 | saldanha
# Processing Record 18 of Set 3 | nancha
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | grand baie
# Processing Record 21 of Set 3 | lexington
# Processing Record 22 of Set 3 | manicore
# Processing Record 23 of Set 3 | pahrump
# Processing Record 24 of Set 3 | petaluma
# Processing Record 25 of Set 3 | huarmey
# Processing Record 26 of Set 3 | brewster
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | solnechnyy
# Processing Record 30 of Set 3 | mercedes
# Processing Record 31 of Set 3 | beyneu
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | mimongo
# Processing Record 34 of Set 3 | januaria
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | port hardy
# Processing Record 37 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | ketchikan
# Processing Record 41 of Set 3 | nome
# Processing Record 42 of Set 3 | zabol
# Processing Record 43 of Set 3 | kahului
# Processing Record 44 of Set 3 | rawson
# Processing Record 45 of Set 3 | shimanovsk
# Processing Record 46 of Set 3 | ewa beach
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | dillon
# Processing Record 49 of Set 3 | saint george
# Processing Record 50 of Set 3 | kamaishi
# Processing Record 1 of Set 4 | podor
# Processing Record 2 of Set 4 | houma
# Processing Record 3 of Set 4 | monrovia
# Processing Record 4 of Set 4 | fukue
# Processing Record 5 of Set 4 | susanville
# Processing Record 6 of Set 4 | tomter
# Processing Record 7 of Set 4 | leningradskiy
# Processing Record 8 of Set 4 | capoterra
# Processing Record 9 of Set 4 | sangmelima
# Processing Record 10 of Set 4 | pingzhuang
# Processing Record 11 of Set 4 | aguimes
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | ambatondrazaka
# Processing Record 14 of Set 4 | colares
# Processing Record 15 of Set 4 | abalak
# Processing Record 16 of Set 4 | san cristobal
# Processing Record 17 of Set 4 | yulara
# Processing Record 18 of Set 4 | ekhabi
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | portland
# Processing Record 21 of Set 4 | mogok
# Processing Record 22 of Set 4 | rocha
# Processing Record 23 of Set 4 | vacaria
# Processing Record 24 of Set 4 | klaksvik
# Processing Record 25 of Set 4 | ankpa
# Processing Record 26 of Set 4 | dawlatabad
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | nikolskoye
# Processing Record 29 of Set 4 | montepuez
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | erzin
# Processing Record 32 of Set 4 | ilulissat
# Processing Record 33 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 4 | port blair
# Processing Record 35 of Set 4 | chuy
# Processing Record 36 of Set 4 | bambous virieux
# Processing Record 37 of Set 4 | kavaratti
# Processing Record 38 of Set 4 | necochea
# Processing Record 39 of Set 4 | harper
# Processing Record 40 of Set 4 | jiroft
# City not found. Skipping...
# Processing Record 41 of Set 4 | storsteinnes
# Processing Record 42 of Set 4 | pangoa
# Processing Record 43 of Set 4 | leticia
# Processing Record 44 of Set 4 | shenjiamen
# Processing Record 45 of Set 4 | lasa
# Processing Record 46 of Set 4 | venice
# Processing Record 47 of Set 4 | dabola
# Processing Record 48 of Set 4 | east london
# Processing Record 49 of Set 4 | caravelas
# Processing Record 50 of Set 4 | saint-pierre
# Processing Record 1 of Set 5 | tuktoyaktuk
# Processing Record 2 of Set 5 | mahabad
# Processing Record 3 of Set 5 | grindavik
# Processing Record 4 of Set 5 | honolulu
# Processing Record 5 of Set 5 | jomalig
# City not found. Skipping...
# Processing Record 6 of Set 5 | tres picos
# Processing Record 7 of Set 5 | naze
# Processing Record 8 of Set 5 | macapa
# Processing Record 9 of Set 5 | lorengau
# Processing Record 10 of Set 5 | coquimbo
# Processing Record 11 of Set 5 | sable-sur-sarthe
# Processing Record 12 of Set 5 | north versailles
# Processing Record 13 of Set 5 | torquay
# Processing Record 14 of Set 5 | koslan
# Processing Record 15 of Set 5 | twentynine palms
# Processing Record 16 of Set 5 | zharkent
# Processing Record 17 of Set 5 | solaro
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | natal
# Processing Record 21 of Set 5 | chiredzi
# Processing Record 22 of Set 5 | qasigiannguit
# Processing Record 23 of Set 5 | palmer
# Processing Record 24 of Set 5 | codrington
# Processing Record 25 of Set 5 | anadyr
# Processing Record 26 of Set 5 | kamenka
# Processing Record 27 of Set 5 | batemans bay
# Processing Record 28 of Set 5 | bulawayo
# Processing Record 29 of Set 5 | estevan
# Processing Record 30 of Set 5 | birjand
# Processing Record 31 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 5 | guhagar
# Processing Record 33 of Set 5 | faanui
# Processing Record 34 of Set 5 | praia
# Processing Record 35 of Set 5 | hay river
# Processing Record 36 of Set 5 | beloha
# Processing Record 37 of Set 5 | yanan
# City not found. Skipping...
# Processing Record 38 of Set 5 | bonthe
# Processing Record 39 of Set 5 | marsa matruh
# Processing Record 40 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 5 | salalah
# Processing Record 42 of Set 5 | the pas
# Processing Record 43 of Set 5 | brae
# Processing Record 44 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 45 of Set 5 | marawi
# Processing Record 46 of Set 5 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | garden city
# Processing Record 49 of Set 5 | constitucion
# Processing Record 50 of Set 5 | kasongo-lunda
# Processing Record 1 of Set 6 | carutapera
# Processing Record 2 of Set 6 | loukhi
# Processing Record 3 of Set 6 | alofi
# Processing Record 4 of Set 6 | miri
# Processing Record 5 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 6 | ponta do sol
# Processing Record 7 of Set 6 | chapais
# Processing Record 8 of Set 6 | bida
# Processing Record 9 of Set 6 | yambio
# Processing Record 10 of Set 6 | inhambane
# Processing Record 11 of Set 6 | taree
# Processing Record 12 of Set 6 | xuddur
# Processing Record 13 of Set 6 | debre tabor
# Processing Record 14 of Set 6 | bilma
# Processing Record 15 of Set 6 | uberaba
# Processing Record 16 of Set 6 | wakefield
# Processing Record 17 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 18 of Set 6 | fort nelson
# Processing Record 19 of Set 6 | singapore
# Processing Record 20 of Set 6 | stromness
# Processing Record 21 of Set 6 | geraldton
# Processing Record 22 of Set 6 | provideniya
# Processing Record 23 of Set 6 | george town
# Processing Record 24 of Set 6 | saint-philippe
# Processing Record 25 of Set 6 | upernavik
# Processing Record 26 of Set 6 | lebu
# Processing Record 27 of Set 6 | hovd
# Processing Record 28 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 6 | gamba
# Processing Record 30 of Set 6 | thohoyandou
# Processing Record 31 of Set 6 | tezu
# Processing Record 32 of Set 6 | gat
# Processing Record 33 of Set 6 | ust-kulom
# Processing Record 34 of Set 6 | tilichiki
# Processing Record 35 of Set 6 | ribeira grande
# Processing Record 36 of Set 6 | ahipara
# Processing Record 37 of Set 6 | sao filipe
# Processing Record 38 of Set 6 | mmabatho
# Processing Record 39 of Set 6 | kaeo
# Processing Record 40 of Set 6 | devils lake
# Processing Record 41 of Set 6 | pitimbu
# Processing Record 42 of Set 6 | nelson bay
# Processing Record 43 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 6 | hamilton
# Processing Record 45 of Set 6 | itarema
# Processing Record 46 of Set 6 | cross lanes
# Processing Record 47 of Set 6 | buluang
# Processing Record 48 of Set 6 | tarata
# Processing Record 49 of Set 6 | santa maria
# Processing Record 50 of Set 6 | shache
# Processing Record 1 of Set 7 | oistins
# Processing Record 2 of Set 7 | krasnoselkup
# Processing Record 3 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 4 of Set 7 | thunder bay
# Processing Record 5 of Set 7 | perelyub
# Processing Record 6 of Set 7 | yinchuan
# Processing Record 7 of Set 7 | linhares
# Processing Record 8 of Set 7 | manbij
# Processing Record 9 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 7 | maningrida
# Processing Record 11 of Set 7 | dalby
# Processing Record 12 of Set 7 | kenai
# Processing Record 13 of Set 7 | chumikan
# Processing Record 14 of Set 7 | mutoko
# Processing Record 15 of Set 7 | berberati
# Processing Record 16 of Set 7 | pisco
# Processing Record 17 of Set 7 | kuytun
# Processing Record 18 of Set 7 | fortuna
# Processing Record 19 of Set 7 | santa cruz
# Processing Record 20 of Set 7 | gerash
# Processing Record 21 of Set 7 | kysyl-syr
# Processing Record 22 of Set 7 | khash
# Processing Record 23 of Set 7 | cornwall
# Processing Record 24 of Set 7 | tiksi
# Processing Record 25 of Set 7 | kruisfontein
# Processing Record 26 of Set 7 | baykit
# Processing Record 27 of Set 7 | namibe
# Processing Record 28 of Set 7 | port lincoln
# Processing Record 29 of Set 7 | huilong
# Processing Record 30 of Set 7 | bonavista
# Processing Record 31 of Set 7 | kayerkan
# Processing Record 32 of Set 7 | nohar
# Processing Record 33 of Set 7 | guane
# Processing Record 34 of Set 7 | bell ville
# Processing Record 35 of Set 7 | sistranda
# Processing Record 36 of Set 7 | halifax
# Processing Record 37 of Set 7 | manzanillo
# Processing Record 38 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 7 | kirakira
# Processing Record 41 of Set 7 | esil
# Processing Record 42 of Set 7 | tiznit
# Processing Record 43 of Set 7 | agirish
# Processing Record 44 of Set 7 | nieuw amsterdam
# Processing Record 45 of Set 7 | khatanga
# Processing Record 46 of Set 7 | zyryanka
# Processing Record 47 of Set 7 | kuito
# Processing Record 48 of Set 7 | bucerias
# Processing Record 49 of Set 7 | key largo
# Processing Record 50 of Set 7 | dublin
# Processing Record 1 of Set 8 | beringovskiy
# Processing Record 2 of Set 8 | guia lopes da laguna
# Processing Record 3 of Set 8 | muana
# Processing Record 4 of Set 8 | kathu
# Processing Record 5 of Set 8 | panguna
# Processing Record 6 of Set 8 | wanaka
# Processing Record 7 of Set 8 | greer
# Processing Record 8 of Set 8 | arraial do cabo
# Processing Record 9 of Set 8 | nova varos
# Processing Record 10 of Set 8 | synya
# Processing Record 11 of Set 8 | nefteyugansk
# Processing Record 12 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 8 | vardo
# Processing Record 14 of Set 8 | waitati
# Processing Record 15 of Set 8 | cherskiy
# Processing Record 16 of Set 8 | winthrop
# Processing Record 17 of Set 8 | torbay
# Processing Record 18 of Set 8 | pervomayskiy
# Processing Record 19 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 8 | westport
# Processing Record 21 of Set 8 | iwaki
# Processing Record 22 of Set 8 | tura
# Processing Record 23 of Set 8 | praia da vitoria
# Processing Record 24 of Set 8 | ocos
# Processing Record 25 of Set 8 | awbari
# Processing Record 26 of Set 8 | sibolga
# Processing Record 27 of Set 8 | kebemer
# City not found. Skipping...
# Processing Record 28 of Set 8 | berdigestyakh
# Processing Record 29 of Set 8 | katsuura
# Processing Record 30 of Set 8 | dubbo
# Processing Record 31 of Set 8 | alyangula
# Processing Record 32 of Set 8 | dawei
# Processing Record 33 of Set 8 | luau
# Processing Record 34 of Set 8 | ulladulla
# Processing Record 35 of Set 8 | williams lake
# Processing Record 36 of Set 8 | vila velha
# Processing Record 37 of Set 8 | warragul
# Processing Record 38 of Set 8 | kangaatsiaq
# Processing Record 39 of Set 8 | shantipur
# Processing Record 40 of Set 8 | zhuozhou
# City not found. Skipping...
# Processing Record 41 of Set 8 | sinjai
# Processing Record 42 of Set 8 | conway
# Processing Record 43 of Set 8 | ayna
# Processing Record 44 of Set 8 | chase
# Processing Record 45 of Set 8 | terrace
# Processing Record 46 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 47 of Set 8 | tahe
# Processing Record 48 of Set 8 | sayyan
# Processing Record 49 of Set 8 | parkhill
# Processing Record 50 of Set 8 | denpasar
# Processing Record 1 of Set 9 | henties bay
# Processing Record 2 of Set 9 | porbandar
# Processing Record 3 of Set 9 | cap malheureux
# Processing Record 4 of Set 9 | khuzdar
# Processing Record 5 of Set 9 | parkes
# Processing Record 6 of Set 9 | ranfurly
# Processing Record 7 of Set 9 | coolum beach
# Processing Record 8 of Set 9 | waipawa
# Processing Record 9 of Set 9 | raudeberg
# Processing Record 10 of Set 9 | beeville
# Processing Record 11 of Set 9 | yanliang
# Processing Record 12 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 13 of Set 9 | dongargaon
# Processing Record 14 of Set 9 | duz
# City not found. Skipping...
# Processing Record 15 of Set 9 | hofn
# Processing Record 16 of Set 9 | marabba
# Processing Record 17 of Set 9 | chiang khong
# Processing Record 18 of Set 9 | svetlogorsk
# Processing Record 19 of Set 9 | sola
# Processing Record 20 of Set 9 | riyadh
# Processing Record 21 of Set 9 | shar
# Processing Record 22 of Set 9 | vila
# Processing Record 23 of Set 9 | grand gaube
# Processing Record 24 of Set 9 | ostrovnoy
# Processing Record 25 of Set 9 | mattru
# Processing Record 26 of Set 9 | dunedin
# Processing Record 27 of Set 9 | soyo
# Processing Record 28 of Set 9 | abu dhabi
# Processing Record 29 of Set 9 | guerrero
# Processing Record 30 of Set 9 | trinidad
# Processing Record 31 of Set 9 | manta
# Processing Record 32 of Set 9 | falun
# Processing Record 33 of Set 9 | vizinga
# Processing Record 34 of Set 9 | bail hongal
# Processing Record 35 of Set 9 | chokurdakh
# Processing Record 36 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 37 of Set 9 | beli potok
# Processing Record 38 of Set 9 | salinas
# Processing Record 39 of Set 9 | nabire
# Processing Record 40 of Set 9 | mount gambier
# Processing Record 41 of Set 9 | touros
# Processing Record 42 of Set 9 | lashio
# Processing Record 43 of Set 9 | coahuayana
# Processing Record 44 of Set 9 | carnot
# Processing Record 45 of Set 9 | srednekolymsk
# Processing Record 46 of Set 9 | ardahan
# Processing Record 47 of Set 9 | palauig
# Processing Record 48 of Set 9 | daru
# Processing Record 49 of Set 9 | isla vista
# Processing Record 50 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 10 | qarchi gak
# Processing Record 2 of Set 10 | pandan
# Processing Record 3 of Set 10 | cairns
# Processing Record 4 of Set 10 | shijak
# Processing Record 5 of Set 10 | porto santo
# Processing Record 6 of Set 10 | senanga
# Processing Record 7 of Set 10 | abyek
# Processing Record 8 of Set 10 | uberlandia
# Processing Record 9 of Set 10 | bonga
# Processing Record 10 of Set 10 | morondava
# Processing Record 11 of Set 10 | laguna
# Processing Record 12 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 13 of Set 10 | maracacume
# Processing Record 14 of Set 10 | tibati
# Processing Record 15 of Set 10 | marzuq
# Processing Record 16 of Set 10 | cockburn town
# Processing Record 17 of Set 10 | birao
# Processing Record 18 of Set 10 | kingaroy
# Processing Record 19 of Set 10 | sembakung
# Processing Record 20 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 10 | urubicha
# Processing Record 23 of Set 10 | arraias
# Processing Record 24 of Set 10 | vitim
# Processing Record 25 of Set 10 | tautira
# Processing Record 26 of Set 10 | qaqortoq
# Processing Record 27 of Set 10 | opuwo
# Processing Record 28 of Set 10 | karratha
# Processing Record 29 of Set 10 | burgos
# Processing Record 30 of Set 10 | belaya gora
# Processing Record 31 of Set 10 | kununurra
# Processing Record 32 of Set 10 | queenstown
# Processing Record 33 of Set 10 | beisfjord
# Processing Record 34 of Set 10 | concordia
# Processing Record 35 of Set 10 | cururupu
# Processing Record 36 of Set 10 | vao
# Processing Record 37 of Set 10 | pimentel
# Processing Record 38 of Set 10 | lastoursville
# Processing Record 39 of Set 10 | guaraniacu
# Processing Record 40 of Set 10 | guigue
# Processing Record 41 of Set 10 | aklavik
# Processing Record 42 of Set 10 | hambantota
# Processing Record 43 of Set 10 | wapakoneta
# Processing Record 44 of Set 10 | port macquarie
# Processing Record 45 of Set 10 | haines junction
# Processing Record 46 of Set 10 | kiruna
# Processing Record 47 of Set 10 | roma
# Processing Record 48 of Set 10 | mizan teferi
# Processing Record 49 of Set 10 | skelleftea
# Processing Record 50 of Set 10 | peniche
# Processing Record 1 of Set 11 | sandpoint
# Processing Record 2 of Set 11 | marsh harbour
# Processing Record 3 of Set 11 | azul
# Processing Record 4 of Set 11 | mao
# Processing Record 5 of Set 11 | wadi musa
# Processing Record 6 of Set 11 | norman wells
# Processing Record 7 of Set 11 | magadan
# Processing Record 8 of Set 11 | mount isa
# Processing Record 9 of Set 11 | turukhansk
# Processing Record 10 of Set 11 | luanda
# Processing Record 11 of Set 11 | hearst
# Processing Record 12 of Set 11 | cuernavaca
# Processing Record 13 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 11 | shangzhi
# Processing Record 15 of Set 11 | iquitos
# Processing Record 16 of Set 11 | celestun
# Processing Record 17 of Set 11 | nador
# Processing Record 18 of Set 11 | kotovsk
# Processing Record 19 of Set 11 | sao geraldo do araguaia
# Processing Record 20 of Set 11 | jalu
# Processing Record 21 of Set 11 | duverge
# Processing Record 22 of Set 11 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 11 | gebze
# Processing Record 24 of Set 11 | makakilo city
# Processing Record 25 of Set 11 | recco
# Processing Record 26 of Set 11 | ambilobe
# Processing Record 27 of Set 11 | joaima
# Processing Record 28 of Set 11 | lavrentiya
# Processing Record 29 of Set 11 | tianpeng
# Processing Record 30 of Set 11 | jepelacio
# Processing Record 31 of Set 11 | prince rupert
# Processing Record 32 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 33 of Set 11 | vanderhoof
# Processing Record 34 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 35 of Set 11 | pervomayskoye
# Processing Record 36 of Set 11 | xique-xique
# Processing Record 37 of Set 11 | kargil
# Processing Record 38 of Set 11 | haapu
# City not found. Skipping...
# Processing Record 39 of Set 11 | tevriz
# Processing Record 40 of Set 11 | sananduva
# Processing Record 41 of Set 11 | hervey bay
# Processing Record 42 of Set 11 | yatou
# Processing Record 43 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 11 | dahra
# Processing Record 45 of Set 11 | salamiyah
# Processing Record 46 of Set 11 | namatanai
# Processing Record 47 of Set 11 | zmeinogorsk
# Processing Record 48 of Set 11 | czluchow
# Processing Record 49 of Set 11 | meulaboh
# Processing Record 50 of Set 11 | batagay-alyta
# Processing Record 1 of Set 12 | hualmay
# Processing Record 2 of Set 12 | kokopo
# Processing Record 3 of Set 12 | kismayo
# Processing Record 4 of Set 12 | guasdualito
# Processing Record 5 of Set 12 | natchez
# Processing Record 6 of Set 12 | kulhudhuffushi
# Processing Record 7 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 8 of Set 12 | worcester
# Processing Record 9 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 12 | freeport
# Processing Record 11 of Set 12 | vuktyl
# Processing Record 12 of Set 12 | lazaro cardenas
# Processing Record 13 of Set 12 | malkangiri
# Processing Record 14 of Set 12 | saint-joseph
# Processing Record 15 of Set 12 | ostuni
# Processing Record 16 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 12 | havre-saint-pierre
# Processing Record 18 of Set 12 | fairhope
# Processing Record 19 of Set 12 | maragogi
# Processing Record 20 of Set 12 | cabedelo
# Processing Record 21 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 22 of Set 12 | san carlos
# Processing Record 23 of Set 12 | preobrazheniye
# Processing Record 24 of Set 12 | masuguru
# Processing Record 25 of Set 12 | japura
# Processing Record 26 of Set 12 | padang
# Processing Record 27 of Set 12 | banepa
# Processing Record 28 of Set 12 | oktyabrskiy
# Processing Record 29 of Set 12 | charters towers
# Processing Record 30 of Set 12 | oktyabrskoye
# Processing Record 31 of Set 12 | adrar
# Processing Record 32 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 33 of Set 12 | correntina
# Processing Record 34 of Set 12 | talavera
# Processing Record 35 of Set 12 | asfi
# Processing Record 36 of Set 12 | hastings
# Processing Record 37 of Set 12 | charlestown
# Processing Record 38 of Set 12 | yafran
# Processing Record 39 of Set 12 | schwabisch hall
# Processing Record 40 of Set 12 | soe
# Processing Record 41 of Set 12 | ajdabiya
# Processing Record 42 of Set 12 | kirovskiy
# Processing Record 43 of Set 12 | goundam
# Processing Record 44 of Set 12 | flin flon
# Processing Record 45 of Set 12 | buala
# Processing Record 46 of Set 12 | bardiyah
# Processing Record 47 of Set 12 | pokaran
# Processing Record 48 of Set 12 | falmouth
# Processing Record 49 of Set 12 | yerbogachen
# Processing Record 50 of Set 12 | sterling
# Processing Record 1 of Set 13 | kaili
# Processing Record 2 of Set 13 | quatre cocos
# Processing Record 3 of Set 13 | hondo
# Processing Record 4 of Set 13 | dunda
# Processing Record 5 of Set 13 | avera
# Processing Record 6 of Set 13 | santa isabel do rio negro
# Processing Record 7 of Set 13 | bielsk podlaski
# Processing Record 8 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 9 of Set 13 | dno
# Processing Record 10 of Set 13 | ha
# City not found. Skipping...
# Processing Record 11 of Set 13 | baherden
# Processing Record 12 of Set 13 | yerofey pavlovich
# Processing Record 13 of Set 13 | osorno
# Processing Record 14 of Set 13 | ixcatlan
# City not found. Skipping...
# Processing Record 15 of Set 13 | omboue
# Processing Record 16 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 13 | tommot
# Processing Record 19 of Set 13 | comodoro rivadavia
# Processing Record 20 of Set 13 | borovskoy
# Processing Record 21 of Set 13 | batsfjord
# Processing Record 22 of Set 13 | gazanjyk
# Processing Record 23 of Set 13 | yashan
# Processing Record 24 of Set 13 | kudahuvadhoo
# Processing Record 25 of Set 13 | svetlaya
# Processing Record 26 of Set 13 | poli
# Processing Record 27 of Set 13 | high level
# Processing Record 28 of Set 13 | bireun
# Processing Record 29 of Set 13 | owando
# Processing Record 30 of Set 13 | samarai
# Processing Record 31 of Set 13 | cardoso
# Processing Record 32 of Set 13 | sault sainte marie
# Processing Record 33 of Set 13 | redmond
# Processing Record 34 of Set 13 | mecca
# Processing Record 35 of Set 13 | seymchan
# Processing Record 36 of Set 13 | grafton
# Processing Record 37 of Set 13 | ancud
# Processing Record 38 of Set 13 | kaele
# Processing Record 39 of Set 13 | yuanli
# Processing Record 40 of Set 13 | uporovo
# Processing Record 41 of Set 13 | sakaiminato
# Processing Record 42 of Set 13 | sisimiut
# Processing Record 43 of Set 13 | valleyview
# Processing Record 44 of Set 13 | atbasar
# Processing Record 45 of Set 13 | kribi
# Processing Record 46 of Set 13 | muzhi
# Processing Record 47 of Set 13 | agua dulce
# Processing Record 48 of Set 13 | balagansk
# Processing Record 49 of Set 13 | akhmim
# Processing Record 50 of Set 13 | mogadishu
# Processing Record 1 of Set 14 | viedma
# Processing Record 2 of Set 14 | mandan
# Processing Record 3 of Set 14 | bara
# Processing Record 4 of Set 14 | north bend
# Processing Record 5 of Set 14 | general pico
# Processing Record 6 of Set 14 | sept-iles
# Processing Record 7 of Set 14 | bathsheba
# Processing Record 8 of Set 14 | ixtapa
# Processing Record 9 of Set 14 | diamantino
# Processing Record 10 of Set 14 | ruteng
# Processing Record 11 of Set 14 | isla mujeres
# Processing Record 12 of Set 14 | shitanjing
# Processing Record 13 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 14 | tekeli
# Processing Record 15 of Set 14 | rorvik
# Processing Record 16 of Set 14 | quelimane
# Processing Record 17 of Set 14 | ojinaga
# Processing Record 18 of Set 14 | mareeba
# Processing Record 19 of Set 14 | ugoofaaru
# Processing Record 20 of Set 14 | poya
# Processing Record 21 of Set 14 | saint albans
# Processing Record 22 of Set 14 | koumac
# Processing Record 23 of Set 14 | kurilsk
# Processing Record 24 of Set 14 | del pilar
# Processing Record 25 of Set 14 | ust-kuyga
# Processing Record 26 of Set 14 | sabzevar
# Processing Record 27 of Set 14 | lokosovo
# Processing Record 28 of Set 14 | acapulco
# Processing Record 29 of Set 14 | staryy krym
# Processing Record 30 of Set 14 | manika
# Processing Record 31 of Set 14 | charleston
# Processing Record 32 of Set 14 | monreal
# Processing Record 33 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 14 | le port
# Processing Record 35 of Set 14 | port keats
# Processing Record 36 of Set 14 | sal rei
# Processing Record 37 of Set 14 | terenos
# Processing Record 38 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 39 of Set 14 | saint-avold
# Processing Record 40 of Set 14 | horodyshche
# Processing Record 41 of Set 14 | nara
# Processing Record 42 of Set 14 | muros
# Processing Record 43 of Set 14 | port hawkesbury
# Processing Record 44 of Set 14 | khoy
# Processing Record 45 of Set 14 | banjar
# Processing Record 46 of Set 14 | yopal
# Processing Record 47 of Set 14 | moose factory
# Processing Record 48 of Set 14 | shwebo
# Processing Record 49 of Set 14 | salinopolis
# Processing Record 50 of Set 14 | andenes
# Processing Record 1 of Set 15 | clemencia
# Processing Record 2 of Set 15 | sarlat-la-caneda
# Processing Record 3 of Set 15 | guangyuan
# Processing Record 4 of Set 15 | prainha
# Processing Record 5 of Set 15 | college
# Processing Record 6 of Set 15 | doha
# Processing Record 7 of Set 15 | atambua
# Processing Record 8 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 9 of Set 15 | isabela
# Processing Record 10 of Set 15 | muzquiz
# City not found. Skipping...
# Processing Record 11 of Set 15 | mandalgovi
# Processing Record 12 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 13 of Set 15 | tamiahua
# Processing Record 14 of Set 15 | laje
# Processing Record 15 of Set 15 | wageningen
# Processing Record 16 of Set 15 | harbour breton
# Processing Record 17 of Set 15 | gravdal
# Processing Record 18 of Set 15 | tabou
# Processing Record 19 of Set 15 | basco
# Processing Record 20 of Set 15 | tinoto
# Processing Record 21 of Set 15 | abdulino
# Processing Record 22 of Set 15 | abu samrah
# Processing Record 23 of Set 15 | shenandoah
# Processing Record 24 of Set 15 | marfino
# Processing Record 25 of Set 15 | kerki
# City not found. Skipping...
# Processing Record 26 of Set 15 | bras-panon
# Processing Record 27 of Set 15 | port moresby
# Processing Record 28 of Set 15 | broome
# Processing Record 29 of Set 15 | tubruq
# City not found. Skipping...
# Processing Record 30 of Set 15 | poum
# Processing Record 31 of Set 15 | vengerovo
# Processing Record 32 of Set 15 | pangnirtung
# Processing Record 33 of Set 15 | agropoli
# Processing Record 34 of Set 15 | karachi
# Processing Record 35 of Set 15 | anamur
# Processing Record 36 of Set 15 | kutum
# Processing Record 37 of Set 15 | noumea
# Processing Record 38 of Set 15 | zilupe
# Processing Record 39 of Set 15 | mweka
# Processing Record 40 of Set 15 | keetmanshoop
# Processing Record 41 of Set 15 | hami
# Processing Record 42 of Set 15 | hassan
# Processing Record 43 of Set 15 | bodden town
# Processing Record 44 of Set 15 | verkhnyaya toyma
# Processing Record 45 of Set 15 | islamkot
# Processing Record 46 of Set 15 | adelaide
# Processing Record 47 of Set 15 | mackay
# Processing Record 48 of Set 15 | loandjili
# Processing Record 49 of Set 15 | goundi
# Processing Record 50 of Set 15 | chipinge
# Processing Record 1 of Set 16 | caborca
# Processing Record 2 of Set 16 | goderich
# Processing Record 3 of Set 16 | ovalle
# Processing Record 4 of Set 16 | charagua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 689

# %%
# city_data_df = pd.DataFrame(city_data)
# city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart -42.8794  147.3294     60.06        63          75
# 1      Butaritari   3.0707  172.7902     82.38        74          94
# 2    Longyearbyen  78.2186   15.6401     37.24        93          75
# 3         Pitanga -24.7572  -51.7614     59.25        84          80
# 4       Jamestown  42.0970  -79.2353     44.71        50           0
# 5          Albany  42.6001  -73.9662     47.34        67         100
# 6        Souillac -20.5167   57.5167     73.78        64          20
# 7       Sinnamary   5.3833  -52.9500     78.35        89         100
# 8          Barrow  71.2906 -156.7887     26.62        80          75
# 9  Severo-Kurilsk  50.6789  156.1250     49.14        69          96
#
#    Wind Speed Country Current Description
# 0       10.36      AU       broken clouds
# 1       16.75      KI     overcast clouds
# 2        6.91      SJ       broken clouds
# 3        2.98      BR       broken clouds
# 4        9.22      US           clear sky
# 5        4.47      US     overcast clouds
# 6       13.80      MU          few clouds
# 7        7.99      GF     overcast clouds
# 8       11.50      US       broken clouds
# 9       13.38      RU     overcast clouds

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart -42.8794  147.3294     60.06        63          75
# 1      Butaritari   3.0707  172.7902     82.38        74          94
# 2    Longyearbyen  78.2186   15.6401     37.24        93          75
# 3         Pitanga -24.7572  -51.7614     59.25        84          80
# 4       Jamestown  42.0970  -79.2353     44.71        50           0
# 5          Albany  42.6001  -73.9662     47.34        67         100
# 6        Souillac -20.5167   57.5167     73.78        64          20
# 7       Sinnamary   5.3833  -52.9500     78.35        89         100
# 8          Barrow  71.2906 -156.7887     26.62        80          75
# 9  Severo-Kurilsk  50.6789  156.1250     49.14        69          96
#
#    Wind Speed Country Current Description
# 0       10.36      AU       broken clouds
# 1       16.75      KI     overcast clouds
# 2        6.91      SJ       broken clouds
# 3        2.98      BR       broken clouds
# 4        9.22      US           clear sky
# 5        4.47      US     overcast clouds
# 6       13.80      MU          few clouds
# 7        7.99      GF     overcast clouds
# 8       11.50      US       broken clouds
# 9       13.38      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

new_column_order = city_data_df.loc[:,["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]]


# new_column_order2 = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]]
# new_column_order2.head()

# Display sample data
# YOUR CODE HERE
new_column_order.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart      AU -42.8794  147.3294     60.06        63          75
# 1      Butaritari      KI   3.0707  172.7902     82.38        74          94
# 2    Longyearbyen      SJ  78.2186   15.6401     37.24        93          75
# 3         Pitanga      BR -24.7572  -51.7614     59.25        84          80
# 4       Jamestown      US  42.0970  -79.2353     44.71        50           0
# 5          Albany      US  42.6001  -73.9662     47.34        67         100
# 6        Souillac      MU -20.5167   57.5167     73.78        64          20
# 7       Sinnamary      GF   5.3833  -52.9500     78.35        89         100
# 8          Barrow      US  71.2906 -156.7887     26.62        80          75
# 9  Severo-Kurilsk      RU  50.6789  156.1250     49.14        69          96
#
#    Wind Speed Current Description
# 0       10.36       broken clouds
# 1       16.75     overcast clouds
# 2        6.91       broken clouds
# 3        2.98       broken clouds
# 4        9.22           clear sky
# 5        4.47     overcast clouds
# 6       13.80          few clouds
# 7        7.99     overcast clouds
# 8       11.50       broken clouds
# 9       13.38     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
new_column_order.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
new_column_order.to_csv(output_data_file)
